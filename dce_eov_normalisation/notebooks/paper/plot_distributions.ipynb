# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for the bell curve
mean = 0       # Mean of the distribution
std_dev = 1    # Standard deviation of the distribution
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
y = (1/(std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

# Create the plot
plt.plot(x, y, color='red', label='Normal Distribution')


# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for the bell curve
mean = 0       # Mean of the distribution
std_dev = 1    # Standard deviation of the distribution
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
y = (1/(std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

# Create the plot
plt.plot(x, y, color='red', linewidth=4)  # Set line thickness using linewidth

# Remove axes and legend
plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

# Remove the surrounding frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

# Show the plot
plt.grid(False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for the bell curve
mean = 0       # Mean of the distribution
std_dev = 1    # Standard deviation of the distribution
x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)
y = (1/(std_dev * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mean) / std_dev) ** 2)

# Create the plot
plt.plot(x, y, color='red', linewidth=4)  # Set line thickness using linewidth

# Remove axes and legend
plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().axes.get_yaxis().set_visible(False)

# Remove the surrounding frame
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

# Remove grid
plt.grid(False)

# Save as SVG (vectorized form)
plt.savefig('bell_curve.svg', format='svg')

# Show the plot
plt.show()
