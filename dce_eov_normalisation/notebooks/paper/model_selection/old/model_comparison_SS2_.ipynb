# %%
# %load_ext autoreload
# %autoreload 2

# %%
#IMPORTS
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from sklearn.metrics import mean_squared_error, r2_score

# %%
loc = 'nw2'
turbine = 'c02'
mode = 'SS2'

# GET THE DATA
package_folder = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
data_folder = os.path.join(package_folder, 'data')
models_folder = os.path.join(package_folder, 'models')
ss2_selected = pd.read_csv(os.path.join(data_folder, 'processed','nw2', turbine+'_ss2_selected_data_large.csv'))
ss2_selected['timestamp'] = pd.to_datetime(ss2_selected['timestamp'])
ss2_selected.set_index('timestamp', inplace=True)

SS1_dbscan = pd.read_parquet(os.path.join(data_folder, 'interim',loc,'tracked_modes', 'dbscan_based', loc+turbine+'_SS1_mode.parquet'))
SS2_dbscan = pd.read_parquet(os.path.join(data_folder, 'interim',loc,'tracked_modes', 'dbscan_based', loc+turbine+'_SS2_mode.parquet'))
FA1_dbscan = pd.read_parquet(os.path.join(data_folder, 'interim',loc,'tracked_modes', 'dbscan_based', loc+turbine+'_FA1_mode.parquet'))
FA2_dbscan = pd.read_parquet(os.path.join(data_folder, 'interim',loc,'tracked_modes', 'dbscan_based', loc+turbine+'_FA2_mode.parquet'))

rfe_selected_data = pd.read_parquet(os.path.join(data_folder, 'interim', loc, 'rfe_selected_data', loc+turbine+'_rfe_selected_data.parquet'))

# %%
# Data availability
1 - rfe_selected_data.isna().sum()/len(rfe_selected_data)
# Out:
# mvbc_WandelaarBuoy_10%_highest_waves        1.000000
# mvbc_WandelaarBuoy_Wave_height              1.000000
# mvbc_WandelaarBuoy_Sea_water_temperature    0.941740
# mvbc_WandelaarMeasuringpile_Tide_TAW        0.989682
# mvbc_WandelaarMeasuringpile_Air_pressure    0.999605
# mean_NW2_C02_rpm                            0.973195
# mean_NW2_C02_yaw                            0.973195
# mean_NW2_C02_pitch                          0.973195
# mean_NW2_C02_power                          0.973195
# mean_NW2_C02_winddirection                  0.973195
# dtype: float64

# %%
##Prepare the training and test data

#choose y_ to be ss2_selected but uniquely indexed keeping the index with hghest value in size column when duplicated
y_ = ss2_selected.copy()
y_ = y_.sort_values(by=['size'], ascending=False)
y_ = y_.loc[~y_.index.duplicated(keep='last')]
y_ = y_.sort_index()

#Synchronize data
Xy = pd.DataFrame(y_['mean_frequency'])
for col in rfe_selected_data.columns:
    Xy[col] = rfe_selected_data[col]
Xy.dropna(inplace=True)
y = Xy.iloc[:,0]
X_ = Xy[rfe_selected_data.columns]

#preprocess the data
from src.data.preprocessing import sin_cos_angle_inputs
from sklearn.model_selection import train_test_split

X = sin_cos_angle_inputs(X_)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# MinMaxnormalization of the data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Standard linear regression
from sklearn.linear_model import LinearRegression

lin_regr = LinearRegression()
lin_regr.fit(X_train, y_train)
lin_regr_pred = pd.DataFrame(lin_regr.predict(X_test), index=y_test.index, columns=['predictions'])
print('Linear Regression', 'MSE: '+str(mean_squared_error(y_test, lin_regr_pred)), 'R2: '+str(r2_score(y_test, lin_regr_pred)))
# Out:
# Linear Regression MSE: 4.7186863529044845e-05 R2: 0.7647044697673796

# %%
# Multivariate Linear Regression
import math
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

mult_lin_regressions = {}
mult_lin_regr_pred = pd.DataFrame(index=y_test.index, columns=['predictions'])
case_lin_regr_pred = {}
caseIDs = pd.read_csv(os.path.join(data_folder, 'interim', 'nw2', 'labeled', loc+turbine+'_case.csv'))
caseIDs.set_index('timestamp', inplace=True)
caseIDs.index = pd.to_datetime(caseIDs.index, utc=True)
for case_ in caseIDs['caseID'].unique():
    try:
        case_lin_regr = LinearRegression()
        case_index = caseIDs[caseIDs['caseID']==case_].index
        case_index_train = case_index[case_index.isin(X_train.index)]
        case_index_test = case_index[case_index.isin(X_test.index)]
        case_lin_regr.fit(X_train.loc[case_index_train], y_train.loc[case_index_train])
        mult_lin_regressions[case_] = case_lin_regr
    except Exception as e1:
        try:
            if math.isnan(case_):
                case_lin_regr = LinearRegression()
                case_index = caseIDs[caseIDs['caseID'].isna()].index
                case_index_train = case_index[case_index.isin(X_train.index)]
                case_index_test = case_index[case_index.isin(X_test.index)]
                case_lin_regr.fit(X_train.loc[case_index_train], y_train.loc[case_index_train])
                mult_lin_regressions[case_] = case_lin_regr
        except Exception as e2:
            print(e1, e2)
            print('Case '+str(case_)+' failed')

mult_lin_regr_pred = pd.DataFrame(columns=['predictions'])
for case_ in caseIDs['caseID'].unique():
    try:
        case_index = caseIDs[caseIDs['caseID']==case_].index
        case_index_test = case_index[case_index.isin(X_test.index)]
        mult_lin_regr_pred = \
            pd.concat(
                [
                mult_lin_regr_pred,
                pd.DataFrame(mult_lin_regressions[case_].predict(X_test.loc[case_index_test]),
                             index=X_test.loc[case_index_test].index,
                             columns=['predictions'])
                ],
                axis=0)
    except Exception as e1:
        try:
            if math.isnan(case_):
                print(case_)
                case_index = caseIDs[caseIDs['caseID'].isna()].index
                case_index_test = case_index[case_index.isin(X_test.index)]
                mult_lin_regr_pred = \
                    pd.concat(
                        [
                        mult_lin_regr_pred,
                        pd.DataFrame(mult_lin_regressions[case_].predict(X_test.loc[case_index_test]), index=X_test.loc[case_index_test].index, columns=['predictions'])
                        ],
                        axis=0)
        except Exception as e2:
            print(e1, e2)
            print('Predicting Case '+str(case_)+' failed')
mult_lin_regr_pred.sort_index(inplace=True)
print('Multivariate Linear Regression',
      'MSE: '+str(mean_squared_error(y_test.loc[mult_lin_regr_pred.index], mult_lin_regr_pred)),
      'R2: '+str(r2_score(y_test.loc[mult_lin_regr_pred.index], mult_lin_regr_pred)))
# Out:
# Found array with 0 sample(s) (shape=(0, 12)) while a minimum of 1 is required by LinearRegression. must be real number, not str
# Case High wind: Turbine reducing output power at extreme wind speeds failed
# nan
# Found array with 0 sample(s) (shape=(0, 12)) while a minimum of 1 is required by LinearRegression. must be real number, not str
# Predicting Case Rated RPM: Turbine rotating at 10.4rpm or 10.445rpm failed
# 'High wind: Turbine reducing output power at extreme wind speeds' must be real number, not str
# Predicting Case High wind: Turbine reducing output power at extreme wind speeds failed
# Multivariate Linear Regression MSE: 4.4374831504075696e-05 R2: 0.7787265622919008

# %% [markdown]
# # Non-optimized models

# %%
# Random Forest Regression
from sklearn.ensemble import RandomForestRegressor
rf_regr = RandomForestRegressor()
rf_regr.fit(X_train, y_train)
rf_regr_pred = pd.DataFrame(rf_regr.predict(X_test), index=y_test.index, columns=['predictions'])
print('Random Forest Regression', 'MSE: '+str(mean_squared_error(y_test, rf_regr_pred)), 'R2: '+str(r2_score(y_test, rf_regr_pred)))
# Out:
# Random Forest Regression MSE: 3.883773420450732e-05 R2: 0.8063370908927181

# %%
# XGBoost regression
from xgboost import XGBRegressor
xgb_regr = XGBRegressor()
xgb_regr.fit(X_train, y_train)
xgb_regr_pred = pd.DataFrame(xgb_regr.predict(X_test), index=y_test.index, columns=['predictions'])
print('XGBoost Regression', 'MSE: '+str(mean_squared_error(y_test, xgb_regr_pred)), 'R2: '+str(r2_score(y_test, xgb_regr_pred)))
# Out:
# XGBoost Regression MSE: 4.3271484614673016e-05 R2: 0.7842283602915224

# %%
# CatBoost regression
from catboost import CatBoostRegressor
cat_regr = CatBoostRegressor()
cat_regr.fit(X_train, y_train, verbose=False)
cat_regr_pred = pd.DataFrame(cat_regr.predict(X_test), index=y_test.index, columns=['predictions'])
print('CatBoost Regression', 'MSE: '+str(mean_squared_error(y_test, cat_regr_pred)), 'R2: '+str(r2_score(y_test, cat_regr_pred)))
# Out:
# CatBoost Regression MSE: 3.810013697163858e-05 R2: 0.8100150919088088

# %%
# Neural Network
from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

target_scaler = MinMaxScaler()
target_scaler.fit(y_train.values.reshape(-1,1))
y_train_scaled = target_scaler.transform(y_train.values.reshape(-1,1))
y_test_scaled = target_scaler.transform(y_test.values.reshape(-1,1))

# Define the early stopping criterion
early_stopping = EarlyStopping(
    monitor='val_mean_squared_error',  # Monitor the validation mean squared error
    patience=10,  # Number of epochs with no improvement after which training will be stopped
    min_delta=1e-07,  # Minimum change to qualify as an improvement
    mode='min',  # Stop training when the quantity monitored has stopped decreasing
    verbose=1,
    restore_best_weights=True  # Restores model weights from the epoch with the best value of the monitored quantity.
)

def build_model(layers_=[100]):
    model = Sequential()
    model.add(Flatten())
    model.add(Dense(units=layers_[0], activation='relu', input_shape=(len(X.columns),)))
    if len(layers_)>1:
        for layer in layers_[1:]:
            model.add(Dense(units=layer, activation='relu'))
    model.add(Dense(1, activation="linear"))
    model.compile(
        optimizer="adam", loss="mean_squared_error", metrics=["mean_squared_error"],
    )
    return model

nn_regr = build_model()
nn_regr.fit(X_train_scaled, y_train, epochs=100, callbacks=[early_stopping], validation_split=0.1, verbose=0)
nn_regr_pred = pd.DataFrame(nn_regr.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
print('Neural Network 1 hidden layer', 'MSE: '+str(mean_squared_error(y_test, nn_regr_pred)), 'R2: '+str(r2_score(y_test, nn_regr_pred)))
# Out:
# WARNING:tensorflow:From c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Restoring model weights from the end of the best epoch: 81.
# Epoch 91: early stopping
# 29/29 [==============================] - 0s 2ms/step
# Neural Network 1 hidden layer MSE: 5.4653134203458405e-05 R2: 0.7274741902826019

# %%
nn_regr = build_model()
nn_regr.fit(X_train_scaled, y_train_scaled, epochs=100, callbacks=[early_stopping], validation_split=0.1, verbose=0)
nn_regr_pred = pd.DataFrame(nn_regr.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
nn_regr_pred_unscaled = target_scaler.inverse_transform(nn_regr_pred)
print('Neural Network 1 hidden layer', 'MSE: '+str(mean_squared_error(y_test, nn_regr_pred_unscaled)), 'R2: '+str(r2_score(y_test, nn_regr_pred_unscaled)))
# Out:
# Restoring model weights from the end of the best epoch: 29.
# Epoch 39: early stopping
# 29/29 [==============================] - 0s 1ms/step
# Neural Network 1 hidden layer MSE: 3.903253154669328e-05 R2: 0.8053657412311891

# %%
nn_regr_2 = build_model([100, 100])
nn_regr_2.fit(X_train_scaled, y_train, epochs=100, callbacks=[early_stopping], validation_split=0.1, verbose=0)
nn_regr_2_pred = pd.DataFrame(nn_regr_2.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
print('Neural Network 2 hidden layers', 'MSE: '+str(mean_squared_error(y_test, nn_regr_2_pred)), 'R2: '+str(r2_score(y_test, nn_regr_2_pred)))
# Out:
# Restoring model weights from the end of the best epoch: 45.
# Epoch 55: early stopping
# 29/29 [==============================] - 0s 2ms/step
# Neural Network 2 hidden layers MSE: 7.012471371873531e-05 R2: 0.6503257376556867

# %%
nn_regr_2 = build_model([100, 100])
nn_regr_2.fit(X_train_scaled, y_train_scaled, epochs=100, callbacks=[early_stopping], validation_split=0.1, verbose=0)
nn_regr_2_pred = pd.DataFrame(nn_regr_2.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
nn_regr_2_pred_unscaled = target_scaler.inverse_transform(nn_regr_2_pred)
print('Neural Network 2 hidden layers', 'MSE: '+str(mean_squared_error(y_test, nn_regr_2_pred_unscaled)), 'R2: '+str(r2_score(y_test, nn_regr_2_pred_unscaled)))
# Out:
# Restoring model weights from the end of the best epoch: 61.
# Epoch 71: early stopping
# 29/29 [==============================] - 0s 1ms/step
# Neural Network 2 hidden layers MSE: 3.952290462566625e-05 R2: 0.802920514212493

# %%
nn_regr_3 = build_model([100, 100, 100])
nn_regr_3.fit(X_train_scaled, y_train, epochs=100, callbacks=[early_stopping], validation_split=0.1, verbose=0)
nn_regr_3_pred = pd.DataFrame(nn_regr_3.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
print('Neural Network 3 hidden layers', 'MSE: '+str(mean_squared_error(y_test, nn_regr_3_pred)), 'R2: '+str(r2_score(y_test, nn_regr_3_pred)))
# Out:
# Restoring model weights from the end of the best epoch: 27.
# Epoch 37: early stopping
# 29/29 [==============================] - 0s 2ms/step
# Neural Network 3 hidden layers MSE: 7.68123033943025e-05 R2: 0.6169783218495437

# %%
nn_regr_3 = build_model([100, 100, 100])
nn_regr_3.fit(X_train_scaled, y_train_scaled, epochs=100, callbacks=[early_stopping], validation_split=0.1, verbose=0)
nn_regr_3_pred = pd.DataFrame(nn_regr_3.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
nn_regr_3_pred_unscaled = target_scaler.inverse_transform(nn_regr_3_pred)
print('Neural Network 3 hidden layers', 'MSE: '+str(mean_squared_error(y_test, nn_regr_3_pred_unscaled)), 'R2: '+str(r2_score(y_test, nn_regr_3_pred_unscaled)))
# Out:
# Restoring model weights from the end of the best epoch: 23.
# Epoch 33: early stopping
# 29/29 [==============================] - 0s 2ms/step
# Neural Network 3 hidden layers MSE: 3.9458581144057085e-05 R2: 0.8032412608478848

# %% [markdown]
# # Hyperopt

# %%
import time
time_limit = 2*60*60 # 2 hours in seconds
mode = 'SS2'
seed = 42

# %%
#Hyperparameter optimization: Bayesian optimization
#Hyperopt functions for hyperparameter optimizations
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials
from src.models.utils import convert_dict
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
import numpy as np
XGB_optimizations = {}


start_time = time.time()

def objective_xgb(space):
    global start_time
    if (time.time() - start_time) > time_limit:
        raise Exception("Time limit exceeded")
    
    model = XGBRegressor(
                                 n_estimators = space['n_estimators'],
                                 max_depth = space['max_depth'],
                                 learning_rate = space['learning_rate'],
                                 colsample_bytree = space['colsample_bytree'],
                                 )
    score = cross_val_score(model,  X_train, y_train, cv=5, scoring='neg_mean_squared_error').mean()
    # We aim to minimize mse 
    return {'loss': -score, 'status': STATUS_OK }

def optimize_xgb(trial):
    space = {
        'n_estimators':hp.uniformint('n_estimators',10,1000),
        'max_depth':hp.uniformint('max_depth',2,20),
        'learning_rate':hp.uniform('learning_rate',0.001,0.5),
        'colsample_bytree': hp.uniform('colsample_bytree',0.1, 1),
    }
    best = \
        fmin(
            fn = objective_xgb,
            space = space,
            algo = tpe.suggest,
            trials = trial,
            max_evals = 100,
            rstate = np.random.RandomState(seed)
            )
    return best
trial2=Trials()
XGB_optimizations[mode] = optimize_xgb(trial2)
XGB_optimizations[mode] = convert_dict(XGB_optimizations)[mode]
# Out:
# 100%|██████████| 100/100 [14:03<00:00,  8.44s/trial, best loss: 4.373629708261872e-05]

# %%
XGB_optimize = XGB_optimizations[mode]
regr_xgb_optimized = \
    XGBRegressor(
        n_estimators = XGB_optimize['n_estimators'],
        max_depth = XGB_optimize['max_depth'],
        learning_rate = XGB_optimize['learning_rate'],
        colsample_bytree = XGB_optimize['colsample_bytree'],
        )
regr_xgb_optimized.fit(X_train, y_train)

regr_xgb_optimized_pred = regr_xgb_optimized.predict(X_test)
regr_xgb_optimized_mse = mean_squared_error(y_test, regr_xgb_optimized_pred)
regr_xgb_optimized_r2 = r2_score(y_test, regr_xgb_optimized_pred)
print("XGBRegressor Optimized MSE:", regr_xgb_optimized_mse, "XGBRegressor Optimized R2:", regr_xgb_optimized_r2)
# Out:
# XGBRegressor Optimized MSE: 3.854262152372167e-05 XGBRegressor Optimized R2: 0.8078086592384525

# %%
# write optimal hyperparameters to a csv file
xgb_optimal_params = pd.DataFrame(XGB_optimizations, index=['optimal_params']).T
xgb_optimal_params.to_csv(os.path.join(models_folder, loc, turbine, 'hyperparameters', mode, 'xgb_optimal_params.csv'))

# %%
from hyperopt import STATUS_FAIL
start_time = time.time()
time_limit_reached = False
time_limit = 4*60*60
def objective_catboost(space):
    global start_time, time_limit_reached
    if (time.time() - start_time) > time_limit:
        time_limit_reached = True
        # Assign a large loss value to indicate failure
        return {'loss': float('inf'), 'status': STATUS_FAIL}

    model = CatBoostRegressor(
        iterations=int(space['iterations']),
        depth=int(space['depth']),
        learning_rate=space['learning_rate'],
        l2_leaf_reg=space['l2_leaf_reg'],
        border_count=int(space['border_count']),
        random_strength=space['random_strength'],
        bagging_temperature=space['bagging_temperature'],
        verbose=False  # to make CatBoost quiet
    )
    score = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error').mean()
    return {'loss': -score, 'status': STATUS_OK}

def optimize_catboost(trial):
    space = {
        'iterations': hp.uniformint('iterations', 20, 1000),
        'depth': hp.uniformint('depth', 2, 16),
        'learning_rate': hp.uniform('learning_rate', 0.01, 0.5),
        'l2_leaf_reg': hp.uniform('l2_leaf_reg', 1, 10),
        'border_count': hp.uniformint('border_count', 32, 255),
        'random_strength': hp.uniform('random_strength', 0, 20),
        'bagging_temperature': hp.uniform('bagging_temperature', 0, 1)
    }
    best = fmin(
        fn=objective_catboost,
        space=space,
        algo=tpe.suggest,
        trials=trial,
        max_evals=50,
        rstate=np.random.RandomState(seed)
    )
    # Check if the time limit flag was set to True
    if time_limit_reached:
        return best
        
    return best

# Example usage
CatBoost_optimizations = {}
trial_catboost = Trials()
CatBoost_optimizations[mode] = optimize_catboost(trial_catboost)
# Out:
# 100%|██████████| 50/50 [3:52:10<00:00, 278.61s/trial, best loss: 4.135340942362036e-05]

# %%
CatBoost_optimizations = convert_dict(CatBoost_optimizations)[mode]
print(CatBoost_optimizations)

# Creating and training the optimized CatBoostRegressor
regr_catboost_optimized = CatBoostRegressor(
    **CatBoost_optimizations,
    verbose=False
)
regr_catboost_optimized.fit(X_train, y_train)

# Prediction and evaluation
regr_catboost_optimized_pred = regr_catboost_optimized.predict(X_test)
regr_catboost_optimized_mse = mean_squared_error(y_test, regr_catboost_optimized_pred)
regr_catboost_optimized_r2 = r2_score(y_test, regr_catboost_optimized_pred)
print("CatBoostRegressor Optimized MSE:", regr_catboost_optimized_mse, "CatBoostRegressor Optimized R2:", regr_catboost_optimized_r2)
# Out:
# {'bagging_temperature': 0.7425247260040191, 'border_count': 34, 'depth': 12, 'iterations': 550, 'l2_leaf_reg': 9.051605002709977, 'learning_rate': 0.034458526754851476, 'random_strength': 7.280394583156862}
# CatBoostRegressor Optimized MSE: 3.73120628229982e-05 CatBoostRegressor Optimized R2: 0.8139447941775944

# %%
# write optimal hyperparameters to a csv file
cb_optimal_params = pd.DataFrame(CatBoost_optimizations, index=['optimal_params']).T
cb_optimal_params.to_csv(os.path.join(models_folder, loc, turbine, 'hyperparameters', mode, 'cb_optimal_params.csv'))

# %%
from src.models.learning_rate import *
from sklearn.model_selection import KFold
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
import numpy as np
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from tensorflow.keras import backend as K

def create_model(hidden_layers, units, batch_normalization):
    model = Sequential()
    model.add(Dense(units[0], input_dim=X_train_scaled.shape[1], activation='relu'))
    if batch_normalization:
        model.add(BatchNormalization())

    for i in range(1, hidden_layers):
        model.add(Dense(units[i], activation='relu'))
        if batch_normalization:
            model.add(BatchNormalization())

    model.add(Dense(1, activation='linear'))  # Assuming a regression problem
    return model

time_limit = 2*60*60
start_time = time.time()
time_limit_reached = False

def objective_nn(params):
    global start_time, time_limit_reached
    if (time.time() - start_time) > time_limit:
        time_limit_reached = True
        # Assign a large loss value to indicate failure
        return {'loss': float('inf'), 'status': STATUS_FAIL}

    # rest of your code
    model = create_model(params['hidden_layers'], [params['units_1'], params['units_2'], params['units_3']], params['batch_normalization'])
    # Learning rate schedulers
    # if params['lr_schedule'] == 'linear':
    #     lr_scheduler = LinearLearningRateScheduler(params['start_lr'], params['end_lr'], 100)
    # elif params['lr_schedule'] == 'sinusoidal':
    #     lr_scheduler = SinusoidalLearningRateScheduler(params['base_lr'], params['max_lr'], 100)
        
    

    kf = KFold(n_splits=5)
    validation_scores = []
    early_stop = EarlyStopping(monitor='val_loss', patience=5)
    for train_index, val_index in kf.split(X_train_scaled):
        # Split data into k-folds
        X_train_kf, X_val_kf = X_train_scaled[train_index], X_train_scaled[val_index]
        y_train_kf, y_val_kf = y_train_scaled[train_index], y_train_scaled[val_index]

        # Create model using the provided parameters
        model = create_model(params['hidden_layers'], [params['units_1'], params['units_2'], params['units_3']], params['batch_normalization'])

        # Optionally add learning rate scheduler
        optimizer = Adam(learning_rate=params['learning_rate'])
        model.compile(
        optimizer=optimizer, loss="mean_squared_error", metrics=["mean_squared_error"],)
        # Fit the model
        model.fit(X_train_kf, y_train_kf, epochs=100, validation_data=(X_val_kf, y_val_kf), callbacks=[early_stop], verbose=0)

        # Evaluate the model on the validation fold
        val_predictions = model.predict(X_val_kf)
        val_score = mean_squared_error(y_val_kf, val_predictions)
        validation_scores.append(val_score)

        # Clear the Keras session to prevent model/layer duplication
        K.clear_session()

    # Compute the average MSE over all folds
    average_score = np.mean(validation_scores)
    return {'loss': average_score, 'status': STATUS_OK}

def optimize(hidden_layers, trial):
    space = {
        'hidden_layers': hidden_layers,
        'units_1': hp.uniform('units_1', 32, 256),
        'units_2': hp.uniform('units_2', 32, 256) if hidden_layers > 1 else None,
        'units_3': hp.uniform('units_3', 32, 256) if hidden_layers > 2 else None,
        'batch_normalization': hp.choice('batch_normalization', [False, True]),
        'learning_rate': hp.uniform('learning_rate', 0.0001, 0.01),
        #'lr_schedule': hp.choice('lr_schedule', ['constant', 'linear', 'sinusoidal']),
        #'start_lr': hp.uniform('start_lr', 0.0001, 0.01),
        #'end_lr': hp.uniform('end_lr', 0.0001, 0.01),
        #'base_lr': hp.uniform('base_lr', 0.0001, 0.01),
        #'max_lr': hp.uniform('max_lr', 0.0001, 0.01),
    }
    best = fmin(
        fn=objective_nn,
        space=space,
        algo=tpe.suggest,
        trials=trial,
        max_evals=50,
        rstate=np.random.RandomState(seed)
    )
    # Check if the time limit flag was set to True
    if time_limit_reached:
        return best
        
    return best

# %%
trial_nn1 = Trials()
time_limit_reached = False
best_hyperparams_1_layer = {}

best_hyperparams_1_layer[mode] = optimize(1, trial_nn1)
best_hyperparams_1_layer = convert_dict(best_hyperparams_1_layer)[mode]
print("Best Hyperparameters for 1 layer:", best_hyperparams_1_layer)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
#  1/23 [>.............................] - ETA: 4s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 14/23 [=================>............] - ETA: 0s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 6ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 7s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 11/23 [=============>................] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 5ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 19s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 1s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 12/23 [==============>...............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 1ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
# 100%|██████████| 50/50 [35:17<00:00, 42.34s/trial, best loss: 0.006303957921722536]
# Best Hyperparameters for 1 layer: {'batch_normalization': 0, 'learning_rate': 0.0005354522045859134, 'units_1': 221.08286972567947}

# %%
from keras.callbacks import LearningRateScheduler
# Train nn1_optimized with optimized hyperparameters

nn1_optimized = create_model(1, [best_hyperparams_1_layer['units_1']], best_hyperparams_1_layer['batch_normalization'])
nn1_optimized.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=best_hyperparams_1_layer['learning_rate']))
early_stop = EarlyStopping(monitor='val_loss', patience=5)
nn1_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop], verbose=0)

# if best_hyperparams_1_layer['lr_schedule'] == 0:#'constant':
#     nn1_optimized = create_model(1, [best_hyperparams_1_layer['units_1']], best_hyperparams_1_layer['batch_normalization'])
#     nn1_optimized.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=best_hyperparams_1_layer['learning_rate']))
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn1_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop], verbose=0)

# elif best_hyperparams_1_layer['lr_schedule'] == 1:#'linear':
#     nn1_optimized = create_model(1, [best_hyperparams_1_layer['units_1']], best_hyperparams_1_layer['batch_normalization'])
#     lr_scheduler = LinearLearningRateScheduler(best_hyperparams_1_layer['start_lr'], best_hyperparams_1_layer['end_lr'], 100)
#     nn1_optimized.compile(loss='mean_squared_error', optimizer=Adam())
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn1_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop, lr_scheduler], verbose=0)

# elif best_hyperparams_1_layer['lr_schedule'] == 2:#'sinusoidal':
#     nn1_optimized = create_model(1, [best_hyperparams_1_layer['units_1']], best_hyperparams_1_layer['batch_normalization'])
#     lr_scheduler = SinusoidalLearningRateScheduler(best_hyperparams_1_layer['base_lr'], best_hyperparams_1_layer['max_lr'], 100)
#     nn1_optimized.compile(loss='mean_squared_error', optimizer=Adam())
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn1_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop, lr_scheduler], verbose=0)

nn1_optimized_pred = pd.DataFrame(nn1_optimized.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
nn1_optimized_pred_unscaled = target_scaler.inverse_transform(nn1_optimized_pred)
nn1_optimized_mse = mean_squared_error(y_test, nn1_optimized_pred_unscaled)
nn1_optimized_r2 = r2_score(y_test, nn1_optimized_pred_unscaled)
print("Neural Network 1 hidden layer Optimized MSE:", nn1_optimized_mse, "Neural Network 1 hidden layer Optimized R2:", nn1_optimized_r2)
# Out:
# 29/29 [==============================] - 0s 2ms/step
# Neural Network 1 hidden layer Optimized MSE: 4.6482883550521815e-05 Neural Network 1 hidden layer Optimized R2: 0.7682148396019368

# %%
trial_nn2 = Trials()
time_limit_reached = False
best_hyperparams_2_layer = {}

best_hyperparams_2_layer[mode] = optimize(2, trial_nn2)
best_hyperparams_2_layer = convert_dict(best_hyperparams_2_layer)[mode]
print("Best Hyperparameters for 2 hidden layers:", best_hyperparams_2_layer)
# Out:
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 19/23 [=======================>......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 13s
# 12/23 [==============>...............] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 1s 5ms/step
#
#  1/23 [>.............................] - ETA: 8s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 10s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 1s 4ms/step
#
#  1/23 [>.............................] - ETA: 7s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 7s
# 14/23 [=================>............] - ETA: 0s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 7ms/step
#
#  1/23 [>.............................] - ETA: 8s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 9s
# 16/23 [===================>..........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 10s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 1s 5ms/step
#
#  1/23 [>.............................] - ETA: 6s
#  7/23 [========>.....................] - ETA: 0s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 6ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 14/23 [=================>............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 6s
# 17/23 [=====================>........] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 7s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 5s
# 18/23 [======================>.......] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 7s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 1s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 22/23 [===========================>..] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 13/23 [===============>..............] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 21/23 [==========================>...] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 2s
# 23/23 [==============================] - 0s 2ms/step
#
#  1/23 [>.............................] - ETA: 4s
# 20/23 [=========================>....] - ETA: 0s
# 23/23 [==============================] - 0s 3ms/step
#
#  1/23 [>.............................] - ETA: 3s
# 15/23 [==================>...........] - ETA: 0s
# 23/23 [==============================] - 0s 4ms/step
#
#  22%|██▏       | 11/50 [11:13<39:46, 61.19s/trial, best loss: 0.006491560602869885]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 5
#       2 time_limit_reached = False
#       3 best_hyperparams_2_layer = {}
# ----> 5 best_hyperparams_2_layer[mode] = optimize(2, trial_nn2)
#       6 best_hyperparams_2_layer = convert_dict(best_hyperparams_2_layer)[mode]
#       7 print("Best Hyperparameters for 2 hidden layers:", best_hyperparams_2_layer)
#
# Cell In[24], line 90, in optimize(hidden_layers, trial)
#      76 def optimize(hidden_layers, trial):
#      77     space = {
#      78         'hidden_layers': hidden_layers,
#      79         'units_1': hp.uniform('units_1', 32, 256),
#    (...)
#      88         #'max_lr': hp.uniform('max_lr', 0.0001, 0.01),
#      89     }
# ---> 90     best = fmin(
#      91         fn=objective_nn,
#      92         space=space,
#      93         algo=tpe.suggest,
#      94         trials=trial,
#      95         max_evals=50,
#      96         rstate=np.random.RandomState(seed)
#      97     )
#      98     # Check if the time limit flag was set to True
#      99     if time_limit_reached:
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\fmin.py:507, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     504 validate_loss_threshold(loss_threshold)
#     506 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 507     return trials.fmin(
#     508         fn,
#     509         space,
#     510         algo=algo,
#     511         max_evals=max_evals,
#     512         timeout=timeout,
#     513         loss_threshold=loss_threshold,
#     514         max_queue_len=max_queue_len,
#     515         rstate=rstate,
#     516         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     517         verbose=verbose,
#     518         catch_eval_exceptions=catch_eval_exceptions,
#     519         return_argmin=return_argmin,
#     520         show_progressbar=show_progressbar,
#     521         early_stop_fn=early_stop_fn,
#     522         trials_save_file=trials_save_file,
#     523     )
#     525 if trials is None:
#     526     if os.path.exists(trials_save_file):
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\base.py:682, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     677 # -- Stop-gap implementation!
#     678 #    fmin should have been a Trials method in the first place
#     679 #    but for now it's still sitting in another file.
#     680 from .fmin import fmin
# --> 682 return fmin(
#     683     fn,
#     684     space,
#     685     algo,
#     686     max_evals,
#     687     timeout=timeout,
#     688     loss_threshold=loss_threshold,
#     689     trials=self,
#     690     rstate=rstate,
#     691     verbose=verbose,
#     692     max_queue_len=max_queue_len,
#     693     allow_trials_fmin=False,  # -- prevent recursion
#     694     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     695     catch_eval_exceptions=catch_eval_exceptions,
#     696     return_argmin=return_argmin,
#     697     show_progressbar=show_progressbar,
#     698     early_stop_fn=early_stop_fn,
#     699     trials_save_file=trials_save_file,
#     700 )
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\fmin.py:553, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     550 rval.catch_eval_exceptions = catch_eval_exceptions
#     552 # next line is where the fmin is actually executed
# --> 553 rval.exhaust()
#     555 if return_argmin:
#     556     if len(trials.trials) == 0:
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\fmin.py:356, in FMinIter.exhaust(self)
#     354 def exhaust(self):
#     355     n_done = len(self.trials)
# --> 356     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     357     self.trials.refresh()
#     358     return self
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\fmin.py:292, in FMinIter.run(self, N, block_until_done)
#     289     time.sleep(self.poll_interval_secs)
#     290 else:
#     291     # -- loop over trials and do the jobs directly
# --> 292     self.serial_evaluate()
#     294 self.trials.refresh()
#     295 if self.trials_save_file != "":
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\fmin.py:170, in FMinIter.serial_evaluate(self, N)
#     168 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     169 try:
# --> 170     result = self.domain.evaluate(spec, ctrl)
#     171 except Exception as e:
#     172     logger.error("job exception: %s" % str(e))
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\hyperopt\base.py:907, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     898 else:
#     899     # -- the "work" of evaluating `config` can be written
#     900     #    either into the pyll part (self.expr)
#     901     #    or the normal Python part (self.fn)
#     902     pyll_rval = pyll.rec_eval(
#     903         self.expr,
#     904         memo=memo,
#     905         print_node_on_error=self.rec_eval_print_node_on_error,
#     906     )
# --> 907     rval = self.fn(pyll_rval)
#     909 if isinstance(rval, (float, int, np.number)):
#     910     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[24], line 62, in objective_nn(params)
#      59 model.compile(
#      60 optimizer=optimizer, loss="mean_squared_error", metrics=["mean_squared_error"],)
#      61 # Fit the model
# ---> 62 model.fit(X_train_kf, y_train_kf, epochs=100, validation_data=(X_val_kf, y_val_kf), callbacks=[early_stop], verbose=0)
#      64 # Evaluate the model on the validation fold
#      65 val_predictions = model.predict(X_val_kf)
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\engine\training.py:1798, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796 callbacks.on_epoch_begin(epoch)
#    1797 with data_handler.catch_stop_iteration():
# -> 1798     for step in data_handler.steps():
#    1799         with tf.profiler.experimental.Trace(
#    1800             "train",
#    1801             epoch_num=epoch,
#    (...)
#    1804             _r=1,
#    1805         ):
#    1806             callbacks.on_train_batch_begin(step)
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\keras\src\engine\data_adapter.py:1411, in DataHandler.steps(self)
#    1409 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410     break
# -> 1411 original_spe = self._steps_per_execution.numpy().item()
#    1412 can_run_full_execution = (
#    1413     original_spe == 1
#    1414     or self._inferred_steps is None
#    1415     or self._inferred_steps - self._current_step >= original_spe
#    1416 )
#    1418 if can_run_full_execution:
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:839, in BaseResourceVariable.read_value(self)
#     830 """Constructs an op which reads the value of this variable.
#     831
#     832 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     836   The value of the variable.
#     837 """
#     838 with ops.name_scope("Read"):
# --> 839   value = self._read_variable_op()
#     840 # Return an identity so it can get placed on whatever device the context
#     841 # specifies instead of the device where the variable is.
#     842 return array_ops.identity(value)
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:818, in BaseResourceVariable._read_variable_op(self, no_copy)
#     816       result = read_and_set_handle(no_copy)
#     817 else:
# --> 818   result = read_and_set_handle(no_copy)
#     820 if not context.executing_eagerly():
#     821   # Note that if a control flow context is active the input of the read op
#     822   # might not actually be the handle. This line bypasses it.
#     823   record.record_operation(
#     824       "ReadVariableOp", [result], [self.handle],
#     825       backward_function=lambda x: [x],
#     826       forward_function=lambda x: [x])
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:808, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     806 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     807   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 808 result = gen_resource_variable_ops.read_variable_op(
#     809     self.handle, self._dtype)
#     810 _maybe_set_handle_data(self._dtype, self.handle, result)
#     811 return result
#
# File c:\Users\Max\anaconda3\envs\dce_eov_norm\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:535, in read_variable_op(resource, dtype, name)
#     533 if tld.is_eager:
#     534   try:
# --> 535     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     536       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     537     return _result
#     538   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# Train nn2_optimized with optimized hyperparameters for 2 hidden layers
nn2_optimized = create_model(2, [best_hyperparams_2_layer['units_1'], best_hyperparams_2_layer['units_2']], best_hyperparams_2_layer['batch_normalization'])
nn2_optimized.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=best_hyperparams_2_layer['learning_rate']))
early_stop = EarlyStopping(monitor='val_loss', patience=5)
nn2_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop], verbose=0)

# if best_hyperparams_2_layer['lr_schedule'] == 0:# 'constant':
#     nn2_optimized = create_model(2, [best_hyperparams_2_layer['units_1'], best_hyperparams_2_layer['units_2']], best_hyperparams_2_layer['batch_normalization'])
#     nn2_optimized.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=best_hyperparams_2_layer['learning_rate']))
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn2_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop], verbose=0)

# elif best_hyperparams_2_layer['lr_schedule'] == 1: #'linear':
#     nn2_optimized = create_model(2, [best_hyperparams_2_layer['units_1'], best_hyperparams_2_layer['units_2']], best_hyperparams_2_layer['batch_normalization'])
#     lr_scheduler = LinearLearningRateScheduler(best_hyperparams_2_layer['start_lr'], best_hyperparams_2_layer['end_lr'], 100)
#     nn2_optimized.compile(loss='mean_squared_error', optimizer=Adam())
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn2_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop, lr_scheduler], verbose=0)

# elif best_hyperparams_2_layer['lr_schedule'] == 2: #'sinusoidal':
#     nn2_optimized = create_model(2, [best_hyperparams_2_layer['units_1'], best_hyperparams_2_layer['units_2']], best_hyperparams_2_layer['batch_normalization'])
#     lr_scheduler = SinusoidalLearningRateScheduler(best_hyperparams_2_layer['base_lr'], best_hyperparams_2_layer['max_lr'], 100)
#     nn2_optimized.compile(loss='mean_squared_error', optimizer=Adam())
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn2_optimized.fit(X_train_scaled, y_train_scaled, epochs=100, validation_split=0.2, callbacks=[early_stop, lr_scheduler], verbose=0)

nn2_optimized_pred = pd.DataFrame(nn2_optimized.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
nn2_optimized_pred_unscaled = target_scaler.inverse_transform(nn2_optimized_pred)
nn2_optimized_mse = mean_squared_error(y_test, nn2_optimized_pred_unscaled)
nn2_optimized_r2 = r2_score(y_test, nn2_optimized_pred_unscaled)
print("Neural Network 2 hidden layers Optimized MSE:", nn2_optimized_mse, "Neural Network 2 hidden layers Optimized R2:", nn2_optimized_r2)

# %%
trial_nn3 = Trials()
time_limit_reached = False
best_hyperparams_3_layer = {}
best_hyperparams_3_layer[mode] = optimize(3, trial_nn3)
best_hyperparams_3_layer = convert_dict(best_hyperparams_3_layer)[mode]
print("Best Hyperparameters for 3 hidden layers:", best_hyperparams_3_layer)
# Out:
# 100%|██████████| 50/50 [46:36<00:00, 55.92s/trial, best loss: 9.148608114628587e-06]
# Best Hyperparameters for 3 hidden layers: {'base_lr': 0.006672602729178487, 'batch_normalization': 0, 'end_lr': 0.00048306391059394383, 'learning_rate': 0.0033757463610422324, 'lr_schedule': 1, 'max_lr': 0.0003859567980082109, 'start_lr': 0.007370321799930674, 'units_1': 114.72954510987545, 'units_2': 175.36224035258155, 'units_3': 162.6747199837697}

# %%
# Train nn3_optimized with optimized hyperparameters for 3 hidden layers
nn3_optimized = create_model(3, [best_hyperparams_3_layer['units_1'], best_hyperparams_3_layer['units_2'], best_hyperparams_3_layer['units_3']], best_hyperparams_3_layer['batch_normalization'])
nn3_optimized.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=best_hyperparams_3_layer['learning_rate']))
early_stop = EarlyStopping(monitor='val_loss', patience=5)
nn3_optimized.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop], verbose=0)

# if best_hyperparams_3_layer['lr_schedule'] == 0:#'constant':
#     nn3_optimized = create_model(3, [best_hyperparams_3_layer['units_1'], best_hyperparams_3_layer['units_2'], best_hyperparams_3_layer['units_3']], best_hyperparams_3_layer['batch_normalization'])
#     nn3_optimized.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=best_hyperparams_3_layer['learning_rate']))
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn3_optimized.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop], verbose=0)

# elif best_hyperparams_3_layer['lr_schedule'] == 1: #'linear':
#     nn3_optimized = create_model(3, [best_hyperparams_3_layer['units_1'], best_hyperparams_3_layer['units_2'], best_hyperparams_3_layer['units_3']], best_hyperparams_3_layer['batch_normalization'])
#     lr_scheduler = LinearLearningRateScheduler(best_hyperparams_3_layer['start_lr'], best_hyperparams_3_layer['end_lr'], 100)
#     nn3_optimized.compile(loss='mean_squared_error', optimizer=Adam())
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn3_optimized.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop, lr_scheduler], verbose=0)

# elif best_hyperparams_3_layer['lr_schedule'] == 2: #'sinusoidal':
#     nn3_optimized = create_model(3, [best_hyperparams_3_layer['units_1'], best_hyperparams_3_layer['units_2'], best_hyperparams_3_layer['units_3']], best_hyperparams_3_layer['batch_normalization'])
#     lr_scheduler = SinusoidalLearningRateScheduler(best_hyperparams_3_layer['base_lr'], best_hyperparams_3_layer['max_lr'], 100)
#     nn3_optimized.compile(loss='mean_squared_error', optimizer=Adam())
#     early_stop = EarlyStopping(monitor='val_loss', patience=5)
#     nn3_optimized.fit(X_train, y_train, epochs=100, validation_split=0.2, callbacks=[early_stop, lr_scheduler], verbose=0)

nn3_optimized_pred = pd.DataFrame(nn3_optimized.predict(X_test_scaled), index=y_test.index, columns=['predictions'])
nn3_optimized_pred_unscaled = target_scaler.inverse_transform(nn3_optimized_pred)
nn3_optimized_mse = mean_squared_error(y_test, nn3_optimized_pred_unscaled)
nn3_optimized_r2 = r2_score(y_test, nn3_optimized_pred_unscaled)
print("Neural Network 3 hidden layers Optimized MSE:", nn3_optimized_mse, "Neural Network 3 hidden layers Optimized R2:", nn3_optimized_r2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 2
#       1 # First, ensure you have the results from the optimization for 3 hidden layers
# ----> 2 best_hyperparams_3_layer = optimize(3)
#       3 print("Best Hyperparameters for 3 hidden layers:", best_hyperparams_3_layer)
#       5 # Train nn3_optimized with optimized hyperparameters for 3 hidden layers
#
# TypeError: optimize() missing 1 required positional argument: 'trial'

# %%
# write optimal hyperparameters to a csv file
nn1_optimal_params = pd.DataFrame(best_hyperparams_1_layer, index=['optimal_params']).T
nn1_optimal_params.to_csv(os.path.join(models_folder, loc, turbine, 'hyperparameters', mode, 'nn1_optimal_params.csv'))
nn2_optimal_params = pd.DataFrame(best_hyperparams_2_layer, index=['optimal_params']).T
nn2_optimal_params.to_csv(os.path.join(models_folder, loc, turbine, 'hyperparameters', mode, 'nn2_optimal_params.csv'))
nn3_optimal_params = pd.DataFrame(best_hyperparams_3_layer, index=['optimal_params']).T
nn3_optimal_params.to_csv(os.path.join(models_folder, loc, turbine, 'hyperparameters', mode, 'nn3_optimal_params.csv'))

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
import numpy as np
import time

# Initialize global variable to track time
start_time = time.time()
time_limit_reached = False

def objective_rf(space):
    global start_time, time_limit_reached
    if (time.time() - start_time) > time_limit:
        time_limit_reached = True
        # Assign a large loss value to indicate failure
        return {'loss': float('inf'), 'status': STATUS_FAIL}

    
    model = RandomForestRegressor(
        n_estimators=int(space['n_estimators']),
        max_depth=int(space['max_depth']),
        min_samples_split=int(space['min_samples_split']),
        min_samples_leaf=int(space['min_samples_leaf']),
    )

    score = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error').mean()
    return {'loss': -score, 'status': STATUS_OK}

def optimize_rf(trial):
    space = {
        'n_estimators': hp.uniformint('n_estimators', 100, 1000),
        'max_depth': hp.uniformint('max_depth', 5, 30),
        'min_samples_split': hp.uniformint('min_samples_split', 2, 10),
        'min_samples_leaf': hp.uniformint('min_samples_leaf', 1, 5),
    }
    best=None
    best = fmin(
            fn=objective_rf,
            space=space,
            algo=tpe.suggest,
            trials=trial,
            max_evals=50,  # Adjust as needed
            rstate=np.random.RandomState(seed)
        )
    # Check if the time limit flag was set to True
    if time_limit_reached:
        print("Optimization stopped due to time limit")
        return best
        
    return best

trial_rf = Trials()
RF_optimizations = {}
RF_optimizations[mode] = optimize_rf(trial_rf)
# Out:
# 100%|██████████| 50/50 [2:03:58<00:00, 148.77s/trial, best loss: 4.3508155997433054e-05]
# Optimization stopped due to time limit

# %%
# Retrieve the best hyperparameters for RandomForestRegressor
RF_optimize = RF_optimizations[mode]

# Create and train the RandomForestRegressor with the optimized hyperparameters
regr_rf_optimized = RandomForestRegressor(
    n_estimators=int(RF_optimize['n_estimators']),
    max_depth=int(RF_optimize['max_depth']),
    min_samples_split=int(RF_optimize['min_samples_split']),
    min_samples_leaf=int(RF_optimize['min_samples_leaf']),
)
regr_rf_optimized.fit(X_train, y_train)

# Predict on the test set
regr_rf_optimized_pred = regr_rf_optimized.predict(X_test)

# Calculate Mean Squared Error and R-squared
regr_rf_optimized_mse = mean_squared_error(y_test, regr_rf_optimized_pred)
regr_rf_optimized_r2 = r2_score(y_test, regr_rf_optimized_pred)

# Print the scores
print("RandomForestRegressor Optimized MSE:", regr_rf_optimized_mse)
print("RandomForestRegressor Optimized R2:", regr_rf_optimized_r2)
# Out:
# RandomForestRegressor Optimized MSE: 3.7219676593997575e-05
# RandomForestRegressor Optimized R2: 0.814405474653327

# %%
# write optimal hyperparameters to a csv file
rf_optimal_params = pd.DataFrame(RF_optimizations, index=['optimal_params']).T
rf_optimal_params.to_csv(os.path.join(models_folder, loc, turbine, 'hyperparameters', mode, 'rf_optimal_params.csv'))
